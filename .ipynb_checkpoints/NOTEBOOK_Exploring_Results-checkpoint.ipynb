# %%
import json
from fun import *

# %%
filename = "zola.json"

with open(filename) as json_file: 
    videos = json.load(json_file)

for k,v in videos.items():
    print("URL : ",k)
    print("Durée de la vidéo : ",v["resume"]["duration_str"])
    print("Récolte Totale : ",v["resume"]["donations_total"])
    print("Don Max : ", v["resume"]["biggest_donation"])
    print("Nombre de dons : ",v["resume"]["donations_n"])
    print("Nombre de dons avec monnaies inconnues : ", v["resume"]["number_of_unknown_donations"])
    print("Les currencies inconnues : ", v["resume"]["unknown_youtube_currencies"])
    print("")
# Out:
# URL :  https://www.youtube.com/watch?v=KHSlJs8iUDs&ab_channel=ZolaHome
# Durée de la vidéo :  1:28:09
# Récolte Totale :  307.1750490883591
# Don Max :  20.0
# Nombre de dons :  38
# Nombre de dons avec monnaies inconnues :  0
# Les currencies inconnues :  []
#
# URL :  https://www.youtube.com/watch?v=0yzdzKz2HsI&ab_channel=ZolaHome
# Durée de la vidéo :  1:05:35
# Récolte Totale :  62.980000000000004
# Don Max :  5.49
# Nombre de dons :  13
# Nombre de dons avec monnaies inconnues :  0
# Les currencies inconnues :  []
#
# URL :  https://www.youtube.com/watch?v=QRi92Y9GpaY&ab_channel=ZolaHome
# Durée de la vidéo :  1:58:32
# Récolte Totale :  1611.8800462729944
# Don Max :  109.99
# Nombre de dons :  85
# Nombre de dons avec monnaies inconnues :  0
# Les currencies inconnues :  []
#
# URL :  https://www.youtube.com/watch?v=JfiyolBCdk8&ab_channel=ZolaHome
# Durée de la vidéo :  4:16:50
# Récolte Totale :  767.4878787020311
# Don Max :  50.0
# Nombre de dons :  88
# ...

# %%
cagnotte = [v["resume"]["donations_total"] for k,v in videos.items()]
sum(cagnotte)
# Out:
# 5185.620687245472

# %%
filename = "naturi.json"

with open(filename) as json_file: 
    videos = json.load(json_file)

for k,v in videos.items():
    print("URL : ",k)
    print("Durée de la vidéo : ",v["resume"]["duration_str"])
    print("Récolte Totale : ",v["resume"]["donations_total"])
    print("Don Max : ", v["resume"]["biggest_donation"])
    print("Nombre de dons : ",v["resume"]["donations_n"])
    print("Nombre de dons avec monnaies inconnues : ", v["resume"]["number_of_unknown_donations"])
    print("Les currencies inconnues : ", v["resume"]["unknown_youtube_currencies"])
    print("")
# Out:
# URL :  https://www.youtube.com/watch?v=b0x7uOAjc3Y&ab_channel=NaturiEbene
# Durée de la vidéo :  2:07:16
# Récolte Totale :  109.63516700775791
# Don Max :  21.99
# Nombre de dons :  16
# Nombre de dons avec monnaies inconnues :  0
# Les currencies inconnues :  []
#
# URL :  https://www.youtube.com/watch?v=kwkMPSWtLzQ&ab_channel=NaturiEbene
# Durée de la vidéo :  2:10:57
# Récolte Totale :  75.46579593948015
# Don Max :  5.0
# Nombre de dons :  18
# Nombre de dons avec monnaies inconnues :  0
# Les currencies inconnues :  []
#
# URL :  https://www.youtube.com/watch?v=ASQvlLcDmSw&ab_channel=NaturiEbene
# Durée de la vidéo :  6:03:35
# Récolte Totale :  242.65293138511856
# Don Max :  25.863183757920602
# Nombre de dons :  31
# Nombre de dons avec monnaies inconnues :  0
# Les currencies inconnues :  []
#
# URL :  https://www.youtube.com/watch?v=UBIBaELNtyI&ab_channel=NaturiEbene
# Durée de la vidéo :  6:53:04
# Récolte Totale :  297.2992571232728
# Don Max :  20.0
# ...

# %%
cagnotte = [v["resume"]["donations_total"] for k,v in videos.items()]
sum(cagnotte)
# Out:
# 5386.966339143112

# %%
filename = "dailywire.json"

with open(filename) as json_file: 
    videos = json.load(json_file)

for k,v in videos.items():
    print("URL : ",k)
    print("Durée de la vidéo : ",v["resume"]["duration_str"])
    print("Récolte Totale : ",v["resume"]["donations_total"])
    print("Don Max : ", v["resume"]["biggest_donation"])
    print("Nombre de dons : ",v["resume"]["donations_n"])
    print("Nombre de dons avec monnaies inconnues : ", v["resume"]["number_of_unknown_donations"])
    print("Les currencies inconnues : ", v["resume"]["unknown_youtube_currencies"])
    print("")
# Out:
# URL :  https://www.youtube.com/watch?v=T6xOSuSIxAs&ab_channel=TheDailyWire
# Durée de la vidéo :  11:54:36
# Récolte Totale :  4056.200004966696
# Don Max :  128.73326467559218
# Nombre de dons :  483
# Nombre de dons avec monnaies inconnues :  0
# Les currencies inconnues :  []

# %%
L = []
for k,v in videos.items():
    for msg in v["messages"]:
        if msg["amount_euros"] == 0:
            L.append(msg)

# %%
for m in L:
    print(m)
    print("")
# Out:
# {'timestamp': 1604438735751545, 'author': 'Perfect Disaster', 'amount': 'ARS\xa050.00', 'message': 'Latinamerica needs Trump elected, we need western values restored. stop marxists', 'header_color': {'rgba': [0, 191, 165, 255], 'hex': '#00bfa5ff'}, 'body_color': {'rgba': [29, 233, 182, 255], 'hex': '#1de9b6ff'}, 'author_id': 'UCa0eN4JZKlE2_VM_c8u8-pw', 'time_text': '1:25:14', 'time_in_seconds': 5114, 'video_offset_time_msec': 5114158, 'url': 'https://www.youtube.com/watch?v=T6xOSuSIxAs&ab_channel=TheDailyWire', 'timestamp_str': '2020-11-03 22:25:35', 'amount_value': 50.0, 'amount_currency': 'ARS', 'currency_code': 'ARS', 'amount_euros': 0}
#
# ...
